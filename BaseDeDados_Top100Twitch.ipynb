# %% [markdown]
# <a href="https://colab.research.google.com/github/andreRiosAraujo/LinkGoogleColab-BaseDeDados/blob/main/BaseDeDados_Top100Twitch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Os 100 canais com mais seguidores da twitch**
# Link: https://www.kaggle.com/datasets/mubashirsidiki/top-50-twitch-channels-by-followers
#
#
# *   Quantidade de dados: 100;
# *   Quantidade de variaveis: 3;
# *   Rank: é a lista de todos os canais de 1 a 100;
# *   Channel: É o nome do canal - Ex: KaiCenat;
# *   Followers: É a quantidade de seguidores daquele canal - Ex:20.2M ;
# *   Tipo de variaveis: qualitativa - KaiCenat. Quantitativa - 20.2M e 19.84M;

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("twitch.csv", sep = ",")
df.head()
# Out:
#    rank    channel followers
# 0     1   KaiCenat     20.2M
# 1     2       ibai    19.84M
# 2     3      Ninja    19.26M
# 3     4  auronplay       17M
# 4     5     Rubius    16.33M

# %%
df.shape
# Out:
# (100, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   rank       100 non-null    int64
#  1   channel    100 non-null    object
#  2   followers  100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#              rank
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df["channel"].describe()
# Out:
# count          100
# unique         100
# top       KaiCenat
# freq             1
# Name: channel, dtype: object

# %%
df["followers"].describe()
# Out:
# count       100
# unique       92
# top       3.36M
# freq          2
# Name: followers, dtype: object

# %%
df = df.drop('rank', axis = 1)

# %%
df.head()
# Out:
#      channel followers
# 0   KaiCenat     20.2M
# 1       ibai    19.84M
# 2      Ninja    19.26M
# 3  auronplay       17M
# 4     Rubius    16.33M

# %%
df.columns = ['canal', 'seguidores']

# %%
df.head()
# Out:
#        canal seguidores
# 0   KaiCenat      20.2M
# 1       ibai     19.84M
# 2      Ninja     19.26M
# 3  auronplay        17M
# 4     Rubius     16.33M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   canal       100 non-null    object
#  1   seguidores  100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
df.describe()
# Out:
#            canal seguidores
# count        100        100
# unique       100         92
# top     KaiCenat      3.36M
# freq           1          2

# %%
df['canal'].value_counts()
# Out:
# canal
# KaiCenat       1
# ibai           1
# Ninja          1
# auronplay      1
# Rubius         1
#               ..
# tarik          1
# kingsleague    1
# Agent00        1
# xCry           1
# Alexby11       1
# Name: count, Length: 100, dtype: int64

# %%
df['seguidores'].value_counts()
# Out:
# seguidores
# 3.36M    2
# 3.26M    2
# 4.8M     2
# 5.79M    2
# 4.29M    2
#         ..
# 3.54M    1
# 3.46M    1
# 3.31M    1
# 3.29M    1
# 3.21M    1
# Name: count, Length: 92, dtype: int64

# %%
df['canal'].value_counts().index
# Out:
# Index(['KaiCenat', 'ibai', 'Ninja', 'auronplay', 'Rubius', 'xQc', 'TheGrefg',
#        'easyliker', 'juansguarnizo', 'Tfue', 'shroud', 'ElMariana', 'edu90',
#        'ElSpreen', 'Jynxzi', 'pokimane', 'sodapoppin', 'Clix', 'caseoh_',
#        'alanzoka', 'TimTheTatman', 'Riot Games', 'Myth', 'tommyinnit',
#        'SypherPK', 'Mongraal', 'AriGameplays', 'loud_coringa', 'AdinRoss',
#        'rivers_gg', 'NICKMERCS', 'ESLCS', 'Quackity', 'summit1g', 'Fortnite',
#        'quiriify', 'AMOURANTH', 'Dream', 'Its_J0schi', 'Robleis', 'Squeezie',
#        'NickEh30', 'moistcr1tikal', 'MontanaBlack88', 'elded', 'Bugha',
#        'loltyler1', 'Tubbo', 'Carreraaa', 'quirify', 'QuackityToo', 'buster',
#        'VALORANT', 'GeorgeNotFound', 'Elraenn', 'RocketLeague', 'SLAKUNTV',
#        'Dakotaz', 'MrSavage', 'Gotaga', 'IlloJuan', 'TenZ', 'stableronaldo',
#        'DrLupo', 'elxokas', 'WilburSoot', 'Gaules', 'Philza', 'RanbooLive',
# ...

# %%
df['seguidores'].value_counts().index
# Out:
# Index(['3.36M', '3.26M', '4.8M', '5.79M', '4.29M', '4.03M', '3.86M', '3.67M',
#        '20.2M', '19.84M', '19.26M', '17M', '10.8M', '9.71M', '9.49M', '9.37M',
#        '8.97M', '8.53M', '8.35M', '7.99M', '16.33M', '12.35M', '12.29M',
#        '12.26M', '11.64M', '11.54M', '11.31M', '10.92M', '7.08M', '7.13M',
#        '7.2M', '7.23M', '7.25M', '7.28M', '7.36M', '7.62M', '6.28M', '6.08M',
#        '6.76M', '7.03M', '6.55M', '6.38M', '6.3M', '6.84M', '5.69M', '5.49M',
#        '5.22M', '5.46M', '4.95M', '4.89M', '4.86M', '4.96M', '4.83M', '4.78M',
#        '5.95M', '6.06M', '5.92M', '5.84M', '5.76M', '6.65M', '4.55M', '4.56M',
#        '4.62M', '4.63M', '4.64M', '4.71M', '4.34M', '4.52M', '4.12M', '4.21M',
#        '4.08M', '4.1M', '4.06M', '4.33M', '4.4M', '4.41M', '3.84M', '3.9M',
#        '3.94M', '3.79M', '3.61M', '3.58M', '3.72M', '3.62M', '3.55M', '3.56M',
#        '3.53M', '3.54M', '3.46M', '3.31M', '3.29M', '3.21M'],
#       dtype='object', name='seguidores')

# %%
df.shape
# Out:
# (100, 2)

# %%
df.sort_values(by='seguidores', ascending=True).head(15)
# Out:
#             canal seguidores
# 12          edu90      10.8M
# 11      ElMariana     10.92M
# 10         shroud     11.31M
# 9            Tfue     11.54M
# 8   juansguarnizo     11.64M
# 7       easyliker     12.26M
# 6        TheGrefg     12.29M
# 5             xQc     12.35M
# 4          Rubius     16.33M
# 3       auronplay        17M
# 2           Ninja     19.26M
# 1            ibai     19.84M
# 0        KaiCenat      20.2M
# 99       Alexby11      3.21M
# 98           xCry      3.26M

# %%
df['seguidores'] = (
    df['seguidores']
    .str.replace('M', '', regex=False)
    .astype(float)
)

# %%
df_top15 = (
    df.sort_values('seguidores', ascending=True)
      .head(15)
)

# %%
plt.figure(figsize = (10, 5))
plt.barh(df_top15['canal'], df_top15['seguidores'], color = ['red', 'black'])
plt.title('Canais da Twitch com mais seguidores')
plt.ylabel('canal')
plt.xlabel('seguidores (Milhões)')
plt.xticks(rotation=45)
# plt.legend()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   canal       100 non-null    object
#  1   seguidores  100 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   canal       100 non-null    object
#  1   seguidores  100 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %%
df.sort_values(by='seguidores', ascending=False).head(15)
# Out:
#             canal  seguidores
# 0        KaiCenat       20.20
# 1            ibai       19.84
# 2           Ninja       19.26
# 3       auronplay       17.00
# 4          Rubius       16.33
# 5             xQc       12.35
# 6        TheGrefg       12.29
# 7       easyliker       12.26
# 8   juansguarnizo       11.64
# 9            Tfue       11.54
# 10         shroud       11.31
# 11      ElMariana       10.92
# 12          edu90       10.80
# 13       ElSpreen        9.71
# 14         Jynxzi        9.49

# %%
df.sort_values(by='seguidores', ascending=True).head(15)
# Out:
#           canal  seguidores
# 99     Alexby11        3.21
# 97      Agent00        3.26
# 98         xCry        3.26
# 96  kingsleague        3.29
# 95        tarik        3.31
# 93         Duke        3.36
# 94   aminematue        3.36
# 92   Fernanfloo        3.46
# 91   karljacobs        3.53
# 90    Staryuuki        3.54
# 89    Asmongold        3.55
# 88   IShowSpeed        3.56
# 87      Cellbit        3.58
# 86        Fanum        3.61
# 85       Ludwig        3.62

# %%
df['seguidores'].max()
# Out:
# 20.2

# %%
df['seguidores'].min()
# Out:
# 3.21

# %%
print(df.head())
# Out:
#        canal  seguidores
# 0   KaiCenat       20.20
# 1       ibai       19.84
# 2      Ninja       19.26
# 3  auronplay       17.00
# 4     Rubius       16.33

# %%
df['seguidores'].value_counts()
# Out:
# seguidores
# 3.36    2
# 3.26    2
# 4.80    2
# 5.79    2
# 4.29    2
#        ..
# 3.54    1
# 3.46    1
# 3.31    1
# 3.29    1
# 3.21    1
# Name: count, Length: 92, dtype: int64

# %%
#gráfico de dispersão
top10Scatter = df.nlargest(10, 'seguidores')
# nlargest = ele alinha os resultados para os maiores resultados
plt.figure(figsize=(10, 10))
plt.scatter(top10Scatter['canal'], top10Scatter['seguidores'], color='orange', alpha=0.6)
plt.title('Dispersão de Popularidade - Top 10 Canais da Twitch')
plt.xlabel('Canal')
plt.ylabel('Seguidores')
plt.xticks(rotation=90)
plt.show()
